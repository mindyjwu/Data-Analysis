# %% [markdown]
# <h1 align=center><font size=5>Databootcamp</font></h1>
# <h1 align=center><font size=5>FALL 2021</font></h1>
# <h1 align=center><font size=5>Problem Set 3</font></h1>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
#     <p>#Write down your name and ID here.</p>
#     <p><b>Name</b>:     Mindy Wu              </p>
#     <p><b>NetID</b>:      mhw370            </p>

# %% [markdown]
# <h4>Instructions</h4>
# <p>Instructions:
#
# •    Submit your answers in a Jupyter notebook with proper markdown to indicate problem numbers
#
# •    Tuning the parameters of the axes object is key in this problem set
#
# •	All plots should be displayed with a title, legend, suitably named x and y labels, properly distributed x and y ticks (points deducted if otherwise)
#
# •	Plots should be of medium to large size so that the visualization doesn’t look over crowded. Very small plots are unreadable (points deducted if otherwise)
#
# •	Position any legends neatly in or outside the plot without over lapping with plot lines (points deducted if otherwise)
#
# •    For every sub‐question on plotting, show the plot (or whatever output) before going on to the next sub‐question
#
# •    In‐line comments are preferred for this assignment but not mandatory
#
# •    No explanations are expected at the end of answers, unless requested
#
# </p>
# <p>You are required to type your answer in the cell below each of the question. Remember to submit the fully executed notebook for it to be considered(Shift+Enter). You can insert cell and use #comments if necessary.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Problems:</h1>

# %% [markdown]
# #### This question asks you to load in data using a url and visualize it.
#
# 1.   Consider the data at:
#
#
# url = 'https://github.com/fivethirtyeight/data/blob/master/college-majors/recent-grads.csv'
#
# The variables are described at:
# https://github.com/fivethirtyeight/data
#
# (in the ‘college‐majors’ folder)
#
# a)   Read the csv file at URL into a data frame named df538. What are its dimensions?
# b)   Construct horizontal bar charts of the top ten majors sorted by median salary
# c)   Plot the bar charts again this time sorted by the salary of the 25th percentile. In each case plot just the variable you sorted on.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
url1 = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/'
url2 ='college-majors/recent-grads.csv'
url = url1 + url2

# %%
# Answer 1a

df538 = pd.read_csv(url, sep=',')
print("This is the dimension for the dataframe: " ,df538.shape)
# Out:
# This is the dimension for the dataframe:  (173, 21)

# %%
# read the dataframe
df538.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
# Answer 1b: Construct horizontal bar charts of the top ten majors sorted by median salary

# set the index as majors and value as salary
plt.style.use('seaborn-whitegrid')
df538[:10].plot.bar(x = 'Major', y = 'Median', figsize = (12,8))

#top_major = df538['Median'].value_counts().index[:10]
#top_ten_majors = df538.loc[df538['Major'].isin(top_major),:]
#top_ten_majors.plot(kind = 'bar', x= 'Major', y = 'Median')
#top_major
#top_major
# Out:
# <AxesSubplot:xlabel='Major'>

# %%
# Answer 1c
# Plot the bar charts again this time sorted by the salary of the 25th percentile. In each case plot just the variable you sorted on.
df538[:10].plot.bar(x = 'Major', y = 'P25th', figsize = (12,10))

# df538['Major'.sort_values().plot.barh(figsize = (4,12))]
# Out:
# <AxesSubplot:xlabel='Major'>

# %%
#df538['P25th'].plot(kind = 'barh',figsize(12,10))

# %% [markdown]
# #### These questions asks you create graphs using matplotlib methods.
#
# 2.	Using the csv file at location http://pages.stern.nyu.edu/~dbackus/Data/debt.csv, create a data frame called debt and do the following with Year as index:
#
# a)   Plot each country’s debt against Year using a suitable plot method. Change the line width to 2. b)   First create figure and axis objects (empty) with plt.subplots(). Then graph public indebtness over the years using our debt data and the axis object we just created. Color the lines red, blue and green. By calling a method on the axis object, change the lower limit on the y axis to zero.
# c)   Make the line for Argentina thicker than the others. Hint: Do this by plotting a separate line
#
# applied to the same axis object.

# %%
# create a dataframe

url = 'http://pages.stern.nyu.edu/~dbackus/Data/debt.csv'
debt = pd.read_csv(url, sep=',')
debt.head()
# Out:
#      ARG   DEU    GRC  Year
# 0  137.5  59.2   98.1  2002
# 1  106.0  64.6   94.9  2004
# 2   61.8  66.3  102.9  2006
# 3   47.0  64.9  108.8  2008
# 4   39.1  80.3  145.7  2010

# %%
# Answer 2a
# Plot each country’s debt against Year using a suitable plot method. Change the line width to 2

debt.plot(x = 'Year', y = ['ARG', 'DEU', 'GRC'])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
# do the following with Year as index
debt = pd.read_csv(url, sep=',', index_col = 'Year')
debt
# Out:
#         ARG   DEU    GRC
# Year
# 2002  137.5  59.2   98.1
# 2004  106.0  64.6   94.9
# 2006   61.8  66.3  102.9
# 2008   47.0  64.9  108.8
# 2010   39.1  80.3  145.7
# 2012   37.3  79.0  156.5
# 2014   48.6  73.1  177.2

# %%
# Answer 2b
# First create figure and axis objects (empty) with plt.subplots(). 
fig, ax = plt.subplots()
# Then graph public indebtness over the years using our debt data and the axis object we just created. 
# Color the lines red, blue and green. 
debt.plot(color = ['red', 'blue', 'green'])
# By calling a method on the axis object, change the lower limit on the y axis to zero.
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
# Answer 2c
# Make the line for Argentina thicker than the others. 
# Hint: Do this by plotting a separate line applied to the same axis object.

#debt['ARG'].plot(color = ['lightcoral'], linewidth = 5)
plt.plot(debt['DEU'], label = 'DEU')
plt.plot(debt['GRC'], label = 'GRC')
plt.plot(debt['ARG'], label = 'ARG',linewidth = 10)

# %% [markdown]
# 3.   data = {'Size': ['1 to 4', '5 to 9', '10 to 19', '20 to 49', '50 to 99', '100 to 249', '250 to 499', '500 to 999','1000 to 2499', '2500 to 4999', '5000 to 9999', '10000+'],'Firms':[2846416,1020772,598153,373345,115544,63845,19389,9588,6088,2287,1250,1357],'Emp': [5998912, 6714924, 8151891, 11425545, 8055535, 9788341, 6611734, 6340775,  8321486, 6738218, 6559020, 32556671]}
#
# bds = pd.DataFrame(data)
#
# bds = bds.set_index('Size')
#
#
# a)   Create a bar chart for the number of employees in each size category.
#
# b)	Create figure and axis objects. Add a horizontal bar chart of the number of firms in each category to the axis object you created. Color the bars red. Use the style 'seaborn‐pastel'.

# %%
data = {'Size': ['1 to 4', '5 to 9', '10 to 19', '20 to 49', '50 to 99', '100 to 249', '250 to 499', '500 to 999','1000 to 2499', '2500 to 4999', '5000 to 9999', '10000+'],'Firms':[2846416,1020772,598153,373345,115544,63845,19389,9588,6088,2287,1250,1357],'Emp': [5998912, 6714924, 8151891, 11425545, 8055535, 9788341, 6611734, 6340775, 8321486, 6738218, 6559020, 32556671]}

# %%
bds = pd.DataFrame(data)
bds = bds.set_index('Size')

# %%
bds
# Out:
#                 Firms       Emp
# Size
# 1 to 4        2846416   5998912
# 5 to 9        1020772   6714924
# 10 to 19       598153   8151891
# 20 to 49       373345  11425545
# 50 to 99       115544   8055535
# 100 to 249      63845   9788341
# 250 to 499      19389   6611734
# 500 to 999       9588   6340775
# 1000 to 2499     6088   8321486
# 2500 to 4999     2287   6738218
# 5000 to 9999     1250   6559020
# 10000+           1357  32556671

# %%
# Answer 3a
#  Create a bar chart for the number of employees in each size category.

# %%
#plt.bar(bds['Size'], bds['Emp'], color = 'blue')
bds['Emp'].plot(kind = 'barh')
plt.xlabel('Size category')
plt.ylabel('Number employees')
plt.title ('Number of employees in each size category')
# Out:
# Text(0.5, 1.0, 'Number of employees in each size category')

# %%
# Answer 3b
# Create figure and axis objects. Add a horizontal bar chart of the number of firms in each category to the axis object you created.
# Color the bars red. Use the style 'seaborn‐pastel'.

import matplotlib.pyplot as plt
import seaborn as sns

bds['Firms'].plot(kind = 'barh', color = 'red')
#bds['Firms'].plot(.barh)

plt.xlabel('Number of firm')
plt.ylabel('Each size category')
plt.title ('Number of employees in each size category')
# Out:
# Text(0.5, 1.0, 'Number of employees in each size category')

# %% [markdown]
# 4.   data = {'BRA': [13.37, 13.30, 14.34, 15.07, 15.46, 15.98, 16.10],'JPN': [33.43, 31.83, 33.71, 34.29, 35.60, 36.79, 37.39],'USA': [48.30, 46.91, 48.31, 49.72, 51.41, 52.94, 54.60],'Year': [2008, 2009, 2010, 2011, 2012, 2013, 2014]}
#
# weo = pd.DataFrame(data)
#
# These numbers are GDP per person in thousands of US dollars, 2008 to 2014, variable PPPPC in the IMF’s
#
# World Economic Outlook Database.
#
#
# a)   For every year, plot the GDP of each country in a stacked bar chart. Use ‘red’ for Brazil, ‘blue’ for USA, ‘yellow’ for Japan.
#
# b)   Change the background color of the plot, make the title larger and in bold face.
#
# c)   Reverse the axes, i.e.let year be y axis and GDP be x. Apply a different color for x and y ticks.
#
# Place the legend outside the plot.

# %%
data = {'BRA': [13.37, 13.30, 14.34, 15.07, 15.46, 15.98, 16.10],
        'JPN': [33.43, 31.83, 33.71, 34.29, 35.60, 36.79, 37.39],
        'USA': [48.30, 46.91, 48.31, 49.72, 51.41, 52.94, 54.60],
        'Year': [2008, 2009, 2010, 2011, 2012, 2013, 2014]}

# %%
weo = pd.DataFrame(data)
weo
# Out:
#      BRA    JPN    USA  Year
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %%
# Answer 4a

# For every year, plot the GDP of each country in a stacked bar chart. 
# Use ‘red’ for Brazil, ‘blue’ for USA, ‘yellow’ for Japan


#fig, ax = plt.subplots()
#width = 0.25
 
#weo.plot(color=['green', 'red', 'blue'])

#labels = ['Brazil', 'Japan', 'United States']



#plt.xlabel('Year')
#plt.ylabel('Countries')
#plt.title('GDP for each country every year')
#plt.show()

weo.plot(x = 'Year', kind = 'bar', stacked = True,
        title = 'GDP for each country every year', color = ['red', 'yellow', 'blue'])
# Out:
# <AxesSubplot:title={'center':'GDP for each country every year'}, xlabel='Year'>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# Answer 4b
# Change the background color of the plot, make the title larger and in bold face.
fig, ax = plt.subplots()

x = np.arange(0, len(weo.index))
plt.style.use('dark_background')

x = np.arange(len(weo['Year']))

#plt.figure(figsize = [12,6])

plt.bar(weo['Year'], weo['USA'], width = 0.1, color = '#8390FA',label= 'United States')
plt.bar(weo['Year'], weo['JPN'], width = 0.1, color = 'cyan',label = 'Japan')
plt.bar(weo['Year'], weo['BRA'], width = 0.1, color = '#24b1d1',label ='Brazil')



#weo.plot(x = 'Year', kind = 'bar', stacked = True,
#        title = 'GDP for each country every year', color = ['red', 'yellow', 'blue'])


plt.xlabel('Year')
plt.ylabel('GDP')
plt.title('GDP for each country per year', fontsize = 27, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'GDP for each country per year')

# %%
# Answer 4c
# Reverse the axes, i.e.let year be y axis and GDP be x. Apply a different color for x and y ticks.

plt.bar(weo['USA'],weo['Year'],  width = 0.1, color = '#8390FA',label= 'United States')
plt.bar(weo['JPN'], weo['Year'], width = 0.1, color = 'cyan',label = 'Japan')
plt.bar( weo['BRA'],weo['Year'], width = 0.1, color = '#24b1d1',label ='Brazil')


plt.xlabel('GDP')
plt.ylabel('Year')
plt.title('GDP for each country per year', fontsize = 10, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'GDP for each country per year')
